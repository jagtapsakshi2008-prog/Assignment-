# %% [markdown]
# # Question 1: List Manipulation Basics

# %%
# Given a list my_list = [10,20,30,40,50,60]:
# change the element at index 2 to 35
# add 70 to the end of the list
# insert 5 at the beginning of the list
# remove the element 40 from the list
# print the final list

# %%
my_list=[10,20,30,40,50,60]

my_list[2]=35
my_list.append(70)
my_list[0]=5
my_list.remove(40)
print(my_list)
# Out:
# [5, 20, 35, 50, 60, 70]

# %% [markdown]
# # Question 2: Sum of Even numbers

# %%
# write python code that iterates through the following list numbers=[12,7,23,48,15,66,9].
# calculate and print the sum of all even numbers in the list.

# %%
list=[12,7,23,48,15,66,9]
sum=0
for i in list:
    if i%2==0:
        sum=sum+i

print("sum of all even numbers=>",sum)
# Out:
# sum of all even numbers=> 126

# %% [markdown]
# # Question 3:Manual List Reversal

# %%
# Given a list data= ['apple','banana','cherry','date','elderberry'] .
# create a new list that contains the element of data in reverse order . 
# you are not allowed to use data.reverse() or data[::-1] .
# you must achieve this using loops and basic list operation

# %%
data= ['apple','banana','cherry','date','elderberry']
rev_data=[]
for i in data:
    rev_data.insert(0,i)

print("original list=>",data)
print("reversed list=>",rev_data)
# Out:
# original list=> ['apple', 'banana', 'cherry', 'date', 'elderberry']
# reversed list=> ['elderberry', 'date', 'cherry', 'banana', 'apple']

# %% [markdown]
# # Question 4: finding the Maximum Element

# %%
# without using the built-in max() function, write code to find and 
# print the largest number in the list values=[8,2,10,5,17,3,14] .

# %%
l=[8,2,10,5,17,3,14]
large=l[0]
for i in l:
    if i>large:
        large=i

print("largest number=>",large)
# Out:
# largest number=> 17

# %% [markdown]
# # Question 5: Count Occurrences

# %%
# Given a list items=['red','blue','green','red','yellow','blue','red'] .
# write code to count how many times the string 'red' appears in the list and print the count .
# do not use the list.count() method.

# %%
items=['red','blue','green','red','yellow','blue','red']
count=0
for i in items:
    if i=="red":
        count+=1
    else:
        pass

print(f"red occurs=> {count} times")
# Out:
# red occurs=> 3 times

# %% [markdown]
# # Question 6: Remove All Occurrences of an element

# %%
# Given a list mixed_numbers=[1,5,2,5,3,5,4,5] .
# write code to remove all instaces of the number 5 from the list .
# the final list should only contain [1,2,3,4] .
# you must achieve this by iterating and creating a new list or 
# modifying the existing one carefully.

# %%
mixed_numbers=[1,5,2,5,3,5,4,5]
new_list=[]
for i in mixed_numbers:
    if i!=5:
        new_list.append(i)

print(new_list)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # Question 7: List Palindrome check

# %%
# Write code to determine if a given list is a palindrome (reads the same forwards and backwards).
# print "palindrome" if it is , and "not palindrome otherwise .
# Test with:

# list1 = [1, 2, 3, 2, 1]
# list2 = ['a', 'b', 'c', 'b', 'd']
# You are not allowed to use [::-1] for comparison.

# %%
list1=[1,2,3,2,1]
list2=['a','b','c','b','d']

for i in [list1,list2]:
    rev_list=[]

    for item in i:
        rev_list.insert(0,item)

    if i==rev_list:
        print(i,"=> Palidrome")
    else:
        print(i,"=> Not Palindrome")
# Out:
# [1, 2, 3, 2, 1] => Palidrome
# ['a', 'b', 'c', 'b', 'd'] => Not Palindrome

# %% [markdown]
# # Question 8:Merge and Sort Two Lists (Manual Sort)

# %%
# Given two lists:

# list_a = [3, 1, 4]
# list_b = [2, 5, 0]
# Combine these two lists into a single list and 
# then sort the combined list in ascending order without using the list.sort() method 
# or the sorted() function.

# You'll need to implement a basic sorting algorithm (e.g., bubble sort logic) using loops.

# %%
list_a=[3,1,4]
list_b=[2,5,0]
combine=list_a+list_b

for i in range(len(combine)):
    for j in range(len(combine) -1 -i):
        if combine[j]>combine[j+1]:
            combine[j],combine[j+1]=combine[j+1],combine[j]

print("sorted list=>",combine)
# Out:
# sorted list=> [0, 1, 2, 3, 4, 5]

# %% [markdown]
# # Question 9: Flatten a Nested List

# %%
# You are given a list that contains integers and other lists (only one level of nesting).
# Example:
# nested_list = [1, [2, 3], 4, [5, 6, 7], 8]

# Write code to create a new flat list containing all the integers from nested_list.
# The result should be:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
nested_list=[1,[2,3],4,[5,6,7],8]
flat_list=[]
for item in nested_list:
    if type(item)==list:
        for num in item:
            flat_list.append(num)
    else:
        flat_list.append(item)

print(flat_list)
# Out:
# [1, [2, 3], 4, [5, 6, 7], 8]

# %% [markdown]
# # Question 10: Find Common Elements

# %%
# list_p = [1, 2, 3, 4, 5]
# list_q = [4, 5, 6, 7, 8]

# Write code to find and print all elements that are common to both lists.
# The order of common elements does not matter.
# You are not allowed to use set operations.

# %%
list_p = [1, 2, 3, 4, 5]
list_q = [4, 5, 6, 7, 8]
for i in list_p:
    for j in list_q:
        if i==j:
            print(i)
# Out:
# 4
# 5
