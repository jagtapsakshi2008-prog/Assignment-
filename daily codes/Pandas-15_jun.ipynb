# %% [markdown]
# # Pandas

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1D data structure in pandas

# %% [markdown]
# # pandas series

# %%
# creating series from list

# %%
import pandas as pd

# %%
l1=[10,20,30,40]
s1=pd.Series(l1)

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Custom index

# %%
s=pd.Series([10,20,30,40],index=['a','b','c','d'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s=pd.Series(["sakshi",17,94],index=['name','age','marks'])

# %%
s
# Out:
# name     sakshi
# age          17
# marks        94
# dtype: object

# %%
# from dictionary

# %%
data={'name':"sakshi",'age':17,'marks':94}

# %%
s=pd.Series(data)

# %%
s
# Out:
# name     sakshi
# age          17
# marks        94
# dtype: object

# %%
data={'name':"soham",'subject':"python",'year':2026,'marks':96}

# %%
s=pd.Series(data)

# %%
s
# Out:
# name        soham
# subject    python
# year         2026
# marks          96
# dtype: object

# %%
s=pd.Series(5,index=['name','age','marks'])

# %%
s
# Out:
# name     5
# age      5
# marks    5
# dtype: int64

# %%
# Attributes

# %%
s=pd.Series([10,20,30,40],index=['a','b','c','d'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30, 40])

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape
# Out:
# (4,)

# %% [markdown]
# # Data manipulation

# %%
s=pd.Series([10,20,30,40])

# %%
print(s*4)
# Out:
# 0     40
# 1     80
# 2    120
# 3    160
# dtype: int64

# %% [markdown]
# # handling missing values

# %%
s=pd.Series([10,None,30,40])

# %%
s
# Out:
# 0    10.0
# 1     NaN
# 2    30.0
# 3    40.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
# dropna => used to remove the missing values

# %%
s.dropna()
# Out:
# 0    10.0
# 2    30.0
# 3    40.0
# dtype: float64

# %%
# fillna => to fill the missing values

# %%
s.fillna(20)
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# dtype: float64

# %% [markdown]
# # Indexing

# %%
s1=pd.Series([10,20,30],index=['a','b','c'])

# %%
s1
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s1['a']
# Out:
# np.int64(10)

# %%
s1['c']
# Out:
# np.int64(30)
