# %%
"""
create a sample text file with some text in it .
""";

# %%
# open the file
f = open("sample.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='r' encoding='cp1252'>

# %%
f.readable()
# Out:
# True

# %%
f.readline()
# Out:
# "The UEFA Euro 2016 final was the concluding match of UEFA Euro 2016, the fifteenth edition of the European Championship, UEFA's quadrennial competition for men's national football teams.\n"

# %%
f.readline()
# Out:
# 'The match was played before 75,868 spectators at the Stade de France (pictured) in Paris on 10 July 2016 between Portugal and hosts France.'

# %%
f.readline()
# Out:
# ''

# %%
f=open("Sample.txt")

# %%
f.readline(10)
# Out:
# 'The UEFA E'

# %%
f.readline(5)
# Out:
# 'uro 2'

# %%
f.tell()
# Out:
# 15

# %%
f.seek(10)
# Out:
# 10

# %%
f.readline(5)
# Out:
# 'uro 2'

# %%
# check readlines

# %%
f=open("Sample.txt")

# %%
data=f.readlines()

# %%
data
# Out:
# ["The UEFA Euro 2016 final was the concluding match of UEFA Euro 2016, the fifteenth edition of the European Championship, UEFA's quadrennial competition for men's national football teams.\n",
#  'The match was played before 75,868 spectators at the Stade de France (pictured) in Paris on 10 July 2016 between Portugal and hosts France.']

# %%
f=open("Sample.txt")

# %%
for line in f:
    print(line)
# Out:
# The UEFA Euro 2016 final was the concluding match of UEFA Euro 2016, the fifteenth edition of the European Championship, UEFA's quadrennial competition for men's national football teams.
#
# The match was played before 75,868 spectators at the Stade de France (pictured) in Paris on 10 July 2016 between Portugal and hosts France.

# %%
# convert the data in upper case

# %%
f=open("Sample.txt")

# %%
for line in data:
    print(line.upper())
# Out:
# THE UEFA EURO 2016 FINAL WAS THE CONCLUDING MATCH OF UEFA EURO 2016, THE FIFTEENTH EDITION OF THE EUROPEAN CHAMPIONSHIP, UEFA'S QUADRENNIAL COMPETITION FOR MEN'S NATIONAL FOOTBALL TEAMS.
#
# THE MATCH WAS PLAYED BEFORE 75,868 SPECTATORS AT THE STADE DE FRANCE (PICTURED) IN PARIS ON 10 JULY 2016 BETWEEN PORTUGAL AND HOSTS FRANCE.

# %%
# read function

# %%
f=open("Sample.txt")

# %%
text=f.read()

# %%
text
# Out:
# "The UEFA Euro 2016 final was the concluding match of UEFA Euro 2016, the fifteenth edition of the European Championship, UEFA's quadrennial competition for men's national football teams.\nThe match was played before 75,868 spectators at the Stade de France (pictured) in Paris on 10 July 2016 between Portugal and hosts France."

# %%
print(text)
# Out:
# The UEFA Euro 2016 final was the concluding match of UEFA Euro 2016, the fifteenth edition of the European Championship, UEFA's quadrennial competition for men's national football teams.
# The match was played before 75,868 spectators at the Stade de France (pictured) in Paris on 10 July 2016 between Portugal and hosts France.

# %%
text.split()
# Out:
# ['The',
#  'UEFA',
#  'Euro',
#  '2016',
#  'final',
#  'was',
#  'the',
#  'concluding',
#  'match',
#  'of',
#  'UEFA',
#  'Euro',
#  '2016,',
#  'the',
#  'fifteenth',
#  'edition',
#  'of',
#  'the',
#  'European',
#  'Championship,',
#  "UEFA's",
#  'quadrennial',
#  'competition',
#  'for',
#  "men's",
#  'national',
#  'football',
#  'teams.',
#  'The',
#  'match',
#  'was',
#  'played',
#  'before',
#  '75,868',
#  'spectators',
#  'at',
#  'the',
#  'Stade',
#  'de',
#  'France',
#  '(pictured)',
#  'in',
#  'Paris',
#  'on',
#  '10',
#  'July',
#  '2016',
#  'between',
#  'Portugal',
#  'and',
#  'hosts',
#  'France.']

# %%
m=open('Demo.txt',encoding='utf-8')

# %%
print(m.read())
# Out:
# महाभारत हे भारतातील सर्वात महान आणि विस्तृत महाकाव्य मानले जाते.
# महर्षी व्यास यांनी याची रचना केली.
# या महाकाव्यात कौरव आणि पांडव यांच्यातील संघर्ष, धर्म-अधर्माचा विचार आणि जीवनातील अनेक मूल्ये सांगितली आहेत.
# कुरुक्षेत्राच्या युद्धात भगवान श्रीकृष्णांनी अर्जुनाला दिलेला भगवद्गीतेचा उपदेश आजही मानवजातीसाठी मार्गदर्शक मानला जातो.
# महाभारत केवळ युद्धाची कथा नसून मानवी स्वभाव, कर्तव्य आणि न्याय यांचे सखोल दर्शन घडवणारे महाकाव्य आहे.

# %%
m.close()

# %%
m.readable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 m.readable()
#
# ValueError: I/O operation on closed file

# %%
# opening a file with context manager

# %%
with open('sample.txt') as f:
    data=f.read()

# %%
f.close()

# %%
print(data)
# Out:
# The UEFA Euro 2016 final was the concluding match of UEFA Euro 2016, the fifteenth edition of the European Championship, UEFA's quadrennial competition for men's national football teams.
# The match was played before 75,868 spectators at the Stade de France (pictured) in Paris on 10 July 2016 between Portugal and hosts France.

# %%
# writing a file

# %%
f=open("myfile.txt",'w')

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %%
lines=[' Following a goalless 90 minutes, which saw Portugal captain Cristiano Ronaldo depart the match through injury, ' , 'Portugal then took the lead in the 108th minute through substitute Eder after his low shot beat France goalkeeper Hugo Lloris.']

# %%
f.writelines(lines)

# %%
f.close()

# %%
# writelines => takes the list of sentences from user and writes them in the file .

# %%
# write()

# %%
sent="frado took the ring. he started his journey to mount doom."

# %%
f=open('myfile.txt','w')
f.write(sent)
f.close()

# %%
# write into a myfile.txt with context manager
# use write function and add 3 seperate lines

# %%
with open("myfile.txt","w") as f:
    f.write("The sun rises in the east.\nPython is a popular programming language.\nPractice makes a person better every day.")

# %%
# simple file copy operation

# %%
s=open("Sample.txt","r")
f=open("myfile.txt","w")

# %%
contents=s.read()
f.write(contents)
f.close()

# %%
# append

# %%
s=open("Sample.txt","a")

# %%
s.write("\ndone")
# Out:
# 5

# %%
s.close()
