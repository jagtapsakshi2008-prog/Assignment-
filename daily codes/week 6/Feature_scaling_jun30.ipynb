# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Social_Network_Ads.csv")
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
# check min and max values inn age and est salary column

# %%
min(df['Age'])
# Out:
# 18.0

# %%
min(df['EstimatedSalary'])
# Out:
# 15000.0

# %%
max(df['Age'])
# Out:
# 150000.0

# %%
max(df['EstimatedSalary'])
# Out:
# 150000.0

# %%
plt.figure(figsize=(16,9))
plt.scatter(df['EstimatedSalary'],df['Age'],c=df['Purchased'])

# %%
# separate data

# %%
x=df[['EstimatedSalary','Age']]
print(x)
# Out:
#      EstimatedSalary   Age
# 0            19000.0  19.0
# 1            20000.0  35.0
# 2            43000.0  26.0
# 3            57000.0  27.0
# 4            76000.0  19.0
# ..               ...   ...
# 395          41000.0  46.0
# 396          23000.0  51.0
# 397          20000.0  50.0
# 398          33000.0  36.0
# 399          36000.0  49.0
#
# [400 rows x 2 columns]

# %%
# normalization

# %%
from sklearn.preprocessing import MinMaxScaler
sca=MinMaxScaler()
x_scaled=sca.fit_transform(x)

# %%
x_scaled
# Out:
# array([[0.02962963, 0.02380952],
#        [0.03703704, 0.4047619 ],
#        [0.20740741, 0.19047619],
#        [0.31111111, 0.21428571],
#        [0.45185185, 0.02380952],
#        [0.31851852, 0.21428571],
#        [0.51111111, 0.21428571],
#        [1.        , 0.33333333],
#        [0.13333333, 0.16666667],
#        [0.37037037, 0.4047619 ],
#        [0.48148148, 0.19047619],
#        [0.27407407, 0.19047619],
#        [0.52592593, 0.04761905],
#        [0.02222222, 0.33333333],
#        [0.4962963 , 0.        ],
#        [0.48148148, 0.26190476],
#        [0.07407407, 0.69047619],
#        [0.08148148, 0.64285714],
#        [0.0962963 , 0.66666667],
#        [0.1037037 , 0.71428571],
#        [0.05185185, 0.64285714],
#        [0.25185185, 0.69047619],
#        [0.19259259, 0.71428571],
#        [0.05185185, 0.64285714],
#        [0.05925926, 0.66666667],
#        [0.03703704, 0.69047619],
#        [0.0962963 , 0.73809524],
#        [0.11111111, 0.69047619],
# ...

# %%
# check min and max value of each column

# %%
x_scaled[:,0].min(),x_scaled[:,0].max()
# Out:
# (np.float64(0.0), np.float64(1.0))

# %%
x_scaled[:,1].min(),x_scaled[:,1].max()
# Out:
# (np.float64(0.0), np.float64(0.9999999999999998))

# %%
# plot the scatter chart yo check the distribution

# %%
plt.figure(figsize=(16,9))
plt.title("data distribution")
plt.scatter(x_scaled[:,1],x_scaled[:,0],c=df['Purchased'])

# %%
from sklearn.preprocessing import StandardScaler

# %%
sl=StandardScaler()
x_scaled=sl.fit_transform(x)

# %%
x_scaled
# Out:
# array([[-1.49004624, -1.78179743],
#        [-1.46068138, -0.25358736],
#        [-0.78528968, -1.11320552],
#        [-0.37418169, -1.01769239],
#        [ 0.18375059, -1.78179743],
#        [-0.34481683, -1.01769239],
#        [ 0.41866944, -1.01769239],
#        [ 2.35674998, -0.54012675],
#        [-1.07893824, -1.20871865],
#        [-0.13926283, -0.25358736],
#        [ 0.30121002, -1.11320552],
#        [-0.52100597, -1.11320552],
#        [ 0.47739916, -1.6862843 ],
#        [-1.51941109, -0.54012675],
#        [ 0.35993973, -1.87731056],
#        [ 0.30121002, -0.82666613],
#        [-1.3138571 ,  0.89257019],
#        [-1.28449224,  0.70154394],
#        [-1.22576253,  0.79705706],
#        [-1.19639767,  0.98808332],
#        [-1.40195167,  0.70154394],
#        [-0.60910054,  0.89257019],
#        [-0.84401939,  0.98808332],
#        [-1.40195167,  0.70154394],
#        [-1.37258681,  0.79705706],
#        [-1.46068138,  0.89257019],
#        [-1.22576253,  1.08359645],
# ...

# %%
x_scaled[:,0].min(),x_scaled[:,0].max()
# Out:
# (np.float64(-1.6075056615492507), np.float64(2.3567499772898386))

# %%
x_scaled[:,1].min(),x_scaled[:,1].max()
# Out:
# (np.float64(-1.8773105578331641), np.float64(2.134240875847471))
