# %% [markdown]
# # 1. Seeds Dataset

# %%
# 1.Read the dataset and separate the input and output columns.
# 2.Plot the graph of class balancing.
# 3.Perform train-test split with 80% and 20%.
# 4.Create logistic regression model.
# 5.Find accuracy, confusion matrix and classification report.
# 6.Perform the prediction of single value entry.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
df = pd.read_csv(r"C:\Users\Sakshi\daily codes\week 8\seeds_dataset.csv")

# %%
df
# Out:
#          0      1       2      3      4      5      6  7
# 0    15.26  14.84  0.8710  5.763  3.312  2.221  5.220  1
# 1    14.88  14.57  0.8811  5.554  3.333  1.018  4.956  1
# 2    14.29  14.09  0.9050  5.291  3.337  2.699  4.825  1
# 3    13.84  13.94  0.8955  5.324  3.379  2.259  4.805  1
# 4    16.14  14.99  0.9034  5.658  3.562  1.355  5.175  1
# ..     ...    ...     ...    ...    ...    ...    ... ..
# 205  12.19  13.20  0.8783  5.137  2.981  3.631  4.870  3
# 206  11.23  12.88  0.8511  5.140  2.795  4.325  5.003  3
# 207  13.20  13.66  0.8883  5.236  3.232  8.315  5.056  3
# 208  11.84  13.21  0.8521  5.175  2.836  3.598  5.044  3
# 209  12.30  13.34  0.8684  5.243  2.974  5.637  5.063  3
#
# [210 rows x 8 columns]

# %%
df.columns=['area','perimeter','compactness','kernel_length','kernel_width','asymmetry_coeff','groove_length','class']

# %%
# split the input & output
x=df.drop('class',axis=1)
y=df['class']

# %%
# class balancing plot
y.value_counts().plot(kind='bar')
plt.title("Class distribution")
plt.show()

# %%
# Train-test split (80-20)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
# logistic regression model
model=LogisticRegression(max_iter=1000)
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# prediction
y_pred=model.predict(x_test)

# %%
# Evalution

# %%
print("ACCURACY:\n",accuracy_score(y_test,y_pred))
print("CONFUSION MATRIX:\n",confusion_matrix(y_test,y_pred))
print("CLASSIFICATION REPORT:\n",classification_report(y_test,y_pred))
# Out:
# ACCURACY:
#  0.9523809523809523
# CONFUSION MATRIX:
#  [[12  0  0]
#  [ 0 13  0]
#  [ 2  0 15]]
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            1       0.86      1.00      0.92        12
#            2       1.00      1.00      1.00        13
#            3       1.00      0.88      0.94        17
#
#     accuracy                           0.95        42
#    macro avg       0.95      0.96      0.95        42
# weighted avg       0.96      0.95      0.95        42

# %%
# Single value prediction
sample = [x.iloc[0]]
print("Single Prediction:", model.predict(sample))
# Out:
# Single Prediction: [1]
# C:\Users\Sakshi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # 2. Balance Scale Dataset

# %%
# 1.Read the dataset and separate the input and output columns.
# 2.Plot the graph of class balancing.
# 3.Perform train-test split with 75% and 25%.
# 4.Create decision tree model.
# 5.Find accuracy, confusion matrix and classification report.
# 6.Perform the prediction of single value entry.
# 7.Plot and save the tree.

# %%
df = pd.read_csv(r"C:\Users\Sakshi\daily codes\week 8\balance_scale_dataset.csv", header=None)

# %%
df;

# %%
df.columns = ['class','left_weight','left_distance','right_weight','right_distance']

# %%
#split input and output
x=df.drop('class',axis=1)
y=df['class']

# %%
#  Class balancing
y.value_counts().plot(kind='bar')
plt.title("Class Distribution")
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
# Decision Tree model
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Predictions
y_pred = model.predict(x_test)

# %%
# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7388535031847133
# Confusion Matrix:
#  [[ 1  6 11]
#  [ 9 59  6]
#  [ 8  1 56]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            B       0.06      0.06      0.06        18
#            L       0.89      0.80      0.84        74
#            R       0.77      0.86      0.81        65
#
#     accuracy                           0.74       157
#    macro avg       0.57      0.57      0.57       157
# weighted avg       0.75      0.74      0.74       157

# %%
# Single value prediction
sample = [[1, 1, 1, 1]]
print("Single Prediction:", model.predict(sample))

# Plot tree
plt.figure(figsize=(12,8))
plot_tree(model, filled=True)
plt.savefig("decision_tree.png")
plt.show()
# Out:
# C:\Users\Sakshi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# Single Prediction: ['L']

# %% [markdown]
# # computer + hardware dataset

# %%
# 1.Read the dataset and separate the input and output columns
# 2.Perform train-test split with 75% and 25%
# 3.Create decision tree model
# 4.Find Mean Absolute Error and accuracy
# 5.Perform the prediction of single value entry
# 6.Plot and save the tree

# %%
df=pd.read_csv(r"C:\Users\Sakshi\daily codes\week 8\computer_hardware_dataset.csv",header=None)

# %%
df;

# %%
df.columns = ["vendor","model","MYCT","MMIN","MMAX","CACH","CHMIN","CHMAX","PRP","ERP"]
