# %% [markdown]
# ## Section A — Strings

# %% [markdown]
# # 1. Write a function analyze_sentence(sentence) that takes a sentence and
# # returns a dictionary with:

# %%
# word_count
# char_count (excluding spaces)
# unique_words (case-insensitive)
# most_frequent_word

# Test it with:
# "The quick brown fox jumps over the lazy dog the fox"

# %%
def analyze_sentence(sentence):
    words=sentence.lower().split()

    word_count=len(words)
    char_count=len(sentence.replace(" ",""))
    unique_words=len(set(words)) # A set stores only unique values.

    freq={}
    for i in words:
        freq[i]=freq.get(i,0)+1
    most_freq=max(freq,key=freq.get)

    return word_count,char_count,unique_words,most_freq

# %%
analyze_sentence("The quick brown fox jumps over the lazy dog the fox")
# Out:
# (11, 41, 8, 'the')

# %% [markdown]
# # 2. Given the string below, do the following and print each result:
#
# # text = "A man a plan a canal Panama"

# %%
# a) Reverse the string without using slicing.

# %%
text="A man a plan a canal panama"
rev=""
for ch in text:
    rev=ch+rev

print("reversed string :",rev)
# Out:
# reversed string : amanap lanac a nalp a nam A

# %%
# b) Check if it is a palindrome, ignoring case and spaces.

# %%
text="A man a plan a canal panama"
clean=text.replace(" ","").lower()
if clean==clean[::-1]:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# palindrome

# %%
# c) Replace every vowel with *.

# %%
text="A man a plan a canal panama"
res=""
for ch in text:
    if ch.lower() in "aeiou":
        res=res+"*"
    else:
        res=res+ch
print(res)
# Out:
# * m*n * pl*n * c*n*l p*n*m*

# %%
# d) Count how many times each vowel appears.

# %%
text="A man a plan a canal panama".lower()
vowels={'a':0,'e':0,'i':0,'o':0,'u':0}
for ch in text:
    if ch in vowels:
        vowels[ch]+=1

print(vowels)
# Out:
# {'a': 10, 'e': 0, 'i': 0, 'o': 0, 'u': 0}

# %% [markdown]
# # 3. Write a function format_report(data) that takes a list of tuples
# # (name, score, grade) and prints a formatted table where:

# %%
    # name is left-aligned (width 15)
    # score is right-aligned (width 6)
    # grade is centered (width 8)

# Use this data:

   #  data = [
   #    ("Alice", 92, "A"),
   #    ("Bob", 78, "B+"),
   #     ("Charlie", 55, "C"),
   #     ("Diana", 100, "A+")
   #     ]

# %%
def format_report(data):
    print(f"{'Name':<15}{'Score':>6}{'Grade':^8}")

    for name, score, grade in data:
        print(f"{name:<15}{score:>6}{grade:^8}")

data = [
    ("Alice", 92, "A"),
    ("Bob", 78, "B+"),
    ("Charlie", 55, "C"),
    ("Diana", 100, "A+")
]

format_report(data)
# Out:
# Name            Score Grade
# Alice              92   A
# Bob                78   B+
# Charlie            55   C
# Diana             100   A+

# %% [markdown]
# # Section B – Data Structures

# %% [markdown]
# # #4. Write a function list_ops(nums) that:

# %%
# a) Removes duplicates while preserving the original order.
# b) Returns a new list with only elements at even indices, squared.
# c) Flattens the nested list into a single list using list comprehension.

#  nums = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
# nested = [[1, 2, 3], [4, 5], [6, 7, 8, 9]]

# %%
def list_ops(nums, nested):
    unique = []
    for num in nums:
        if num not in unique:
            unique.append(num)

    even_squared = [nums[i] ** 2 for i in range(0, len(nums), 2)]
    flattened = [item for sublist in nested for item in sublist]

    return unique, even_squared, flattened


nums = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
nested = [[1, 2, 3], [4, 5], [6, 7, 8, 9]]

unique_nums, even_squared, flattened = list_ops(nums, nested)

print("unique numbers:",unique_nums)
print(" squared number:",even_squared)
print("flattened number",flattened)
# Out:
# unique numbers: [3, 1, 4, 5, 9, 2, 6]
#  squared number: [9, 16, 25, 4, 25, 25]
# flattened number [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# # 5. Given the tuple below:
# # employee = ('E042', 'Riya Sharma', 'Data Science', 72000, 'Pune')

# %%
# a) Unpack it into meaningful variable names.

# b) Use * unpacking to separate the first element, the last, and everything in between.

# c) Write a function update_salary(emp_tuple, new_salary) that returns a new tuple with the salary updated.

# %%
employee = ('E042', 'Riya Sharma', 'Data Science', 72000, 'Pune')

# a) Unpack into meaningful variable names
emp_id, name, department, salary, city = employee

print("Employee ID:", emp_id)
print("Name:", name)
print("Department:", department)
print("Salary:", salary)
print("City:", city)


# b) Use * unpacking
first, *middle, last = employee

print("\nFirst Element:", first)
print("Middle Elements:", middle)
print("Last Element:", last)


# c) Function to update salary
def update_salary(emp_tuple, new_salary):
    emp_id, name, department, salary, city = emp_tuple
    return (emp_id, name, department, new_salary, city)

# Function call
updated_employee = update_salary(employee, 80000)

print("\nOriginal Tuple:", employee)
print("Updated Tuple:", updated_employee)
# Out:
# Employee ID: E042
# Name: Riya Sharma
# Department: Data Science
# Salary: 72000
# City: Pune
#
# First Element: E042
# Middle Elements: ['Riya Sharma', 'Data Science', 72000]
# Last Element: Pune
#
# Original Tuple: ('E042', 'Riya Sharma', 'Data Science', 72000, 'Pune')
# Updated Tuple: ('E042', 'Riya Sharma', 'Data Science', 80000, 'Pune')

# %% [markdown]
# # 6. Using the sets below, find:
# # batch_a = {'Aarav', 'Priya', 'Karan', 'Meera', 'Sahil'}
# # batch_b = {'Karan', 'Meera', 'Tanvi', 'Rohan'}
# # batch_c = {'Priya', 'Aarav'}

# %%
# a) Students present in both batches.

# b) Students in batch_a but not in batch_b.

# c) All unique students across both batches.

# d) Whether batch_c is a subset of batch_a.

# %%
batch_a = {'Aarav', 'Priya', 'Karan', 'Meera', 'Sahil'}
batch_b = {'Karan', 'Meera', 'Tanvi', 'Rohan'}
batch_c = {'Priya', 'Aarav'}

print("common studebts:",(batch_a & batch_b))
print("Students in batch_a but not in batch_b :",batch_a - batch_b)
print("umique students:",batch_a | batch_b)
print("batch_c is a subset of batch_a :",batch_c.issubset(batch_a))
# Out:
# common studebts: {'Meera', 'Karan'}
# Students in batch_a but not in batch_b : {'Sahil', 'Priya', 'Aarav'}
# umique students: {'Aarav', 'Tanvi', 'Meera', 'Priya', 'Rohan', 'Karan', 'Sahil'}
# batch_c is a subset of batch_a : True

# %% [markdown]
# # 7. Write a function inventory_manager(records) that takes a list of tuples (product, category, quantity, price) and  returns a dictionary grouped by category.

# %%
# Each category should have:

# total_items
# total_value
# A list of product names

# Use:

# records = [
#    ('Laptop', 'Electronics', 10, 55000),
#    ('Mouse', 'Electronics', 50, 499),
#    ('Desk', 'Furniture', 8, 12000),
#    ('Chair', 'Furniture', 15, 4500),
#    ('Pen', 'Stationery', 200, 20)
# ]

# %%
records = [
    ('Laptop', 'Electronics', 10, 55000),
    ('Mouse', 'Electronics', 50, 499),
    ('Desk', 'Furniture', 8, 12000),
    ('Chair', 'Furniture', 15, 4500),
    ('Pen', 'Stationery', 200, 20)
]

def inventory_manager(records):
    inventory = {}

    for product, category, quantity, price in records:
        if category not in inventory:
            inventory[category] = {
                'total_items': 0,
                'total_value': 0,
                'products': []
            }

        inventory[category]['total_items'] += quantity
        inventory[category]['total_value'] += quantity * price
        inventory[category]['products'].append(product)

    return inventory


# Function call
result = inventory_manager(records)

# Display result
for category, details in result.items():
    print(f"\nCategory: {category}")
    print("Total Items:", details['total_items'])
    print("Total Value:", details['total_value'])
    print("Products:", details['products'])
# Out:
# Category: Electronics
# Total Items: 60
# Total Value: 574950
# Products: ['Laptop', 'Mouse']
#
# Category: Furniture
# Total Items: 23
# Total Value: 163500
# Products: ['Desk', 'Chair']
#
# Category: Stationery
# Total Items: 200
# Total Value: 4000
# Products: ['Pen']

# %% [markdown]
# # Section C — Functions and Modules

# %% [markdown]
# # 8. Implement the following:

# %%
# a) A function power_all(*args, exp=2) that returns a list of each number raised to exp.

# b) A function profile(**kwargs) that prints each key-value pair as:

# Key : Value

# c) Use a lambda inside sorted() to sort the list of dictionaries below by cgpa in descending order.

# students = [
#    {"name": "Arjun", "cgpa": 8.4},
#    {"name": "Sanya", "cgpa": 9.1},
#    {"name": "Dev", "cgpa": 7.8}
#  ]

# %%
def power_all(*args, exp=2):
    return [num ** exp for num in args]

print(power_all(2, 3, 4))         
print(power_all(2, 3, 4, exp=3))   


def profile(**kwargs):
    for key, value in kwargs.items():
        print(f"{key} : {value}")

profile(name="Arjun", age=20, city="Pune")


# c) Sort list of dictionaries by cgpa in descending order

students = [
    {"name": "Arjun", "cgpa": 8.4},
    {"name": "Sanya", "cgpa": 9.1},
    {"name": "Dev", "cgpa": 7.8}
]

sorted_students = sorted(students, key=lambda x: x["cgpa"], reverse=True)

print("Students sorted by CGPA (descending):")
for student in sorted_students:
    print(student)
# Out:
# [4, 9, 16]
# [8, 27, 64]
# name : Arjun
# age : 20
# city : Pune
# Students sorted by CGPA (descending):
# {'name': 'Sanya', 'cgpa': 9.1}
# {'name': 'Arjun', 'cgpa': 8.4}
# {'name': 'Dev', 'cgpa': 7.8}

# %%
# 10. Complete the following:

# %%
# a) Write a closure make_multiplier(n) that returns a function multiplying its input by n. 
# Create triple and quintuple using it.

# %%
def make_multiplier(n):
    def multiplier(x):
        return x * n
    return multiplier

# Creating functions
triple = make_multiplier(3)
quintuple = make_multiplier(5)

print("Triple of 10 =", triple(10))
print("Quintuple of 10 =", quintuple(10))
# Out:
# Triple of 10 = 30
# Quintuple of 10 = 50

# %%
# b) Write a decorator @timer that prints the execution time of any function it wraps.
# Apply it to slow_sum(n) which computes the sum of squares from 1 to n.

# %%
import time

# Decorator
def timer(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print("Execution Time:", end - start, "seconds")
        return result
    return wrapper

@timer
def slow_sum(n):
    return sum(i*i for i in range(1, n+1))

print("Sum =", slow_sum(100000))
# Out:
# Execution Time: 0.026397228240966797 seconds
# Sum = 333338333350000

# %%
# c) Write a decorator @validate_positive that raises a ValueError if any argument is zero or negative. 
# Apply it to safe_sqrt(x).

# %%
import math

# Decorator
def validate_positive(func):
    def wrapper(*args, **kwargs):
        for arg in args:
            if arg <= 0:
                raise ValueError("Arguments must be positive")
        return func(*args, **kwargs)
    return wrapper

@validate_positive
def safe_sqrt(x):
    return math.sqrt(x)

print(safe_sqrt(25))

# print(safe_sqrt(-4))  # Raises ValueError
# Out:
# 5.0
