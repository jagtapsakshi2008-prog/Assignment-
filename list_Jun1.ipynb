# %% [markdown]
# # Data structure

# %% [markdown]
# # 1.list

# %%
l1=[23,45,67,43,12]

# %%
print(l1)
# Out:
# [23, 45, 67, 43, 12]

# %%
# list are heterogeneous in nature and duplication is allowed

# %%
l2=[23,45,67,90,89,12,"python","java",23,45]

# %%
print(l2)
# Out:
# [23, 45, 67, 90, 89, 12, 'python', 'java', 23, 45]

# %%
# list's insertion order is fixed

# %%
l1
# Out:
# [23, 45, 67, 43, 12]

# %%
l2[2]
# Out:
# 67

# %%
l2[-3]
# Out:
# 'java'

# %%
l2[1]=100

# %%
l2
# Out:
# [23, 100, 67, 90, 89, 12, 'python', 'java', 23, 45]

# %%
l2[7]=23

# %%
l2
# Out:
# [23, 100, 67, 90, 89, 12, 'python', 23, 23, 45]

# %%
# slicing

# %%
l=[21,23,45,67,89,11]

# %%
l
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
print(l[1:4])
# Out:
# [23, 45, 67]

# %%
l[1:-2]
# Out:
# [23, 45, 67]

# %%
l[0:5:2]
# Out:
# [21, 45, 89]

# %%
# reversing the list

# %%
l[::-1]
# Out:
# [11, 89, 67, 45, 23, 21]

# %%
l[1:4]=[100,200,300]

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l1=[12,34,56,23]

# %%
del l1[-2]

# %%
l1
# Out:
# [12, 34, 23]

# %%
# membership operator

# %%
 89 in l
# Out:
# True

# %%
1038 in l
# Out:
# False

# %%
l*2
# Out:
# [21, 100, 200, 300, 89, 11, 21, 100, 200, 300, 89, 11]

# %%
# arithmetic operator

# %%
print(l)
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
# string function

# %%
'ok'*3
# Out:
# 'okokok'

# %%
# repetition of list

# %%
l*2
# Out:
# [21, 100, 200, 300, 89, 11, 21, 100, 200, 300, 89, 11]

# %%
l+[60,70,80]
# Out:
# [21, 100, 200, 300, 89, 11, 60, 70, 80]

# %%
# take two diffrent list and add them

# %%
list1=[1,2,3]
list2=[4,5,6]
print(list1+list2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# iteration over list and print square of the each element

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
for i in l:
    print(i**2)
# Out:
# 441
# 10000
# 40000
# 90000
# 7921
# 121

# %%
# print odd numbers in the list

# %%
for i in l:
    if(i%2==1):
        print(i)
# Out:
# 21
# 89
# 11

# %%
# list comprehention->[expression for loop if_condition]

# %%
new1=[i**2 for i in l]

# %%
new1
# Out:
# [441, 10000, 40000, 90000, 7921, 121]

# %%
new2=[i for i in l if i%2==1]

# %%
new2
# Out:
# [21, 89, 11]

# %%
names=['Aryan','athrv','samruddhi','swaraj','Sukanya','shivraj']

# %%
# create a new list with names which start with 's' or'S'

# %%
newl3=[i for i in names  if i.startswith('s') or i.startswith('S')]

# %%
newl3
# Out:
# ['samruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
for i in names:
    if i.lower().startswith('s'):
        print(i)
# Out:
# samruddhi
# swaraj
# Sukanya
# shivraj

# %%
for i in names:
    if i[0]=='s' or i[0]=='S':
        print(i)
# Out:
# samruddhi
# swaraj
# Sukanya
# shivraj

# %% [markdown]
# # list function

# %%
print(l)
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
len(l)
# Out:
# 6

# %%
max(l)
# Out:
# 300

# %%
min(l)
# Out:
# 11

# %%
sorted(l)
# Out:
# [11, 21, 89, 100, 200, 300]

# %%
sorted(l,reverse=True)
# Out:
# [300, 200, 100, 89, 21, 11]

# %% [markdown]
# # list methods

# %%
# append

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l.append(1000)

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l1=[1,2,3]
l2=[1,2,3]

# %%
l1.append([100,200])
l2.extend([100,200])

# %%
l1
# Out:
# [1, 2, 3, [100, 200]]

# %%
l2
# Out:
# [1, 2, 3, 100, 200]

# %%
# to access 200 only
# Out:
# [100, 200]

# %%
l1[3][1]
# Out:
# 200

# %%
l1[3][1]=400

# %%
l1
# Out:
# [1, 2, 3, [100, 400]]

# %%
# insert

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l.insert(1,78)

# %%
l
# Out:
# [21, 78, 100, 200, 300, 89, 11, 1000]

# %%
l.remove(78)

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
# pop

# %%
l.pop()
# Out:
# 1000

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l.pop(3)
# Out:
# 300

# %%
l.index(89)
# Out:
# 3

# %%
l.sort()

# %%
l
# Out:
# [11, 21, 89, 100, 200]

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [200, 100, 89, 21, 11]
